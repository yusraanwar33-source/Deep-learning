# %% [markdown]
# <a href="https://colab.research.google.com/github/yusraanwar33-source/Deep-learning/blob/main/movie_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment analysis of movie reviews using LSTM (deep learning model)

# %%
def predict_sentiment(review_text):
    tokens = [word_index.get(word, 2) for word in review_text.split()]
    tokens = pad_sequences([tokens], maxlen=250)
    pred = model.predict(tokens)[0][0]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

x_test = pad_sequences(x_test, maxlen=250, padding='post')

loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.8516 - loss: 0.3523
# Test Loss: 0.3523
# Test Accuracy: 0.8516

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Get word_index to use with the predict_sentiment function
word_index = imdb.get_word_index()

# Create a reverse word index to decode reviews (optional, but useful for debugging)
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# Helper function to decode a review (for context)
def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

# Define the predict_sentiment function here to ensure it's available
def predict_sentiment(review_text):
    tokens = [word_index.get(word, 2) for word in review_text.split()]
    tokens = pad_sequences([tokens], maxlen=250)
    pred = model.predict(tokens)[0][0]
    return pred # Added return statement

# Demonstrate predicting sentiment for a sample review
sample_review_text = "This movie was fantastic! I absolutely loved it and would recommend it to everyone."
prediction = predict_sentiment(sample_review_text)

if prediction > 0.5:
    print(f"The sentiment of the review is positive (score: {prediction:.2f})")
else:
    print(f"The sentiment of the review is negative (score: {prediction:.2f})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# The sentiment of the review is positive (score: 0.70)
